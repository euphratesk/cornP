# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

#Set plotting style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('deep')

# %%
conn = sqlite3.connect('papcorns.sqlite')

# %%
#Import Users Table into dataframe

users_df = pd.read_sql_query("SELECT*FROM users;",conn)

# %%
#Import Users Event Table into dataframe

events_df = pd.read_sql_query("SELECT*FROM user_events;",conn)

# %%
#Check columns and records's amount of Users df

users_df.shape
# Out:
# (1002, 5)

# %%
#Check columns and records's amount of Users Event df

events_df.shape
# Out:
# (3486, 5)

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  1002 non-null   int64
#  1   created_at          1002 non-null   object
#  2   attribution_source  1002 non-null   object
#  3   country             1002 non-null   object
#  4   name                1002 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 39.3+ KB

# %%
events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3486 entries, 0 to 3485
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          3486 non-null   int64
#  1   created_at  3486 non-null   object
#  2   user_id     3486 non-null   int64
#  3   event_name  3486 non-null   object
#  4   amount_usd  1231 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 136.3+ KB

# %%
#5 head records of Users df

users_df.head()
# Out:
#    id           created_at attribution_source country          name
# 0   1  2024-05-07T00:00:00          instagram      US     Eve Brown
# 1   2  2024-10-12T00:00:00          instagram      NL   Frank Moore
# 2   3  2024-10-15T00:00:00             tiktok      TR  Ivy Anderson
# 3   4  2024-08-28T00:00:00             tiktok      TR   Alice Brown
# 4   5  2024-04-03T00:00:00            organic      NL     Bob Moore

# %%
#5 head records of Users Event df

events_df.head()
# Out:
#    id           created_at  user_id       event_name  amount_usd
# 0   1  2024-05-07T00:00:00        1      app_install         NaN
# 1   2  2024-05-12T00:00:00        1    trial_started         NaN
# 2   3  2024-05-24T00:00:00        1  trial_cancelled         NaN
# 3   4  2024-10-12T00:00:00        2      app_install         NaN
# 4   5  2024-10-13T00:00:00        2    trial_started         NaN

# %%
#lets remove id in events_df. user_id is reference od id in users_df


events_df = events_df.drop('id',axis = 1, inplace = True)

# %%
#Check Missing values by columns Users df

#Note  No missing values in Users df

users_df.isnull().sum()
# Out:
# id                    0
# created_at            0
# attribution_source    0
# country               0
# name                  0
# dtype: int64

# %%
#Check Missing values by columns Users Event df

#Note!... 2255 of 3486 records of amount_usd column are null that is too high
#Take a look and give address what category have missing values 'most'

events_df.isnull().sum()
# Out:
# id               0
# created_at       0
# user_id          0
# event_name       0
# amount_usd    2255
# dtype: int64

# %%
#There is a problem with created column cronologically. There are some date at the future so those values should be removed from dataset

events_df['created_at'] = pd.to_datetime(events_df['created_at'])

# %%
events_df.shape
# Out:
# (3486, 5)

# %%
with pd.option_context('display.max_rows',None):
    print(events_df)
# Out:
#         id           created_at  user_id              event_name  amount_usd
# 0        1  2024-05-07T00:00:00        1             app_install         NaN
# 1        2  2024-05-12T00:00:00        1           trial_started         NaN
# 2        3  2024-05-24T00:00:00        1         trial_cancelled         NaN
# 3        4  2024-10-12T00:00:00        2             app_install         NaN
# 4        5  2024-10-13T00:00:00        2           trial_started         NaN
# 5        6  2024-10-20T00:00:00        2    subscription_started        8.99
# 6        7  2024-11-19T00:00:00        2    subscription_renewed        8.99
# 7        8  2024-12-19T00:00:00        2    subscription_renewed        8.99
# 8        9  2025-01-18T00:00:00        2    subscription_renewed        8.99
# 9       10  2025-02-12T00:00:00        2  subscription_cancelled         NaN
# 10      11  2024-10-15T00:00:00        3             app_install         NaN
# 11      12  2024-10-19T00:00:00        3           trial_started         NaN
# 12      13  2024-10-21T00:00:00        3    subscription_started        4.99
# 13      14  2024-11-20T00:00:00        3    subscription_renewed        4.99
# 14      15  2024-12-20T00:00:00        3    subscription_renewed        4.99
# 15      16  2025-01-19T00:00:00        3    subscription_renewed        4.99
# 16      17  2025-01-20T00:00:00        3  subscription_cancelled         NaN
# 17      18  2024-08-28T00:00:00        4             app_install         NaN
# 18      19  2024-08-31T00:00:00        4           trial_started         NaN
# 19      20  2024-09-06T00:00:00        4         trial_cancelled         NaN
# 20      21  2024-04-03T00:00:00        5             app_install         NaN
# 21      22  2024-03-08T00:00:00        6             app_install         NaN
# 22      23  2024-03-09T00:00:00        6           trial_started         NaN
# 23      24  2024-03-18T00:00:00        6         trial_cancelled         NaN
# 24      25  2024-10-21T00:00:00        7             app_install         NaN
# 25      26  2024-08-14T00:00:00        8             app_install         NaN
# 26      27  2024-08-15T00:00:00        8           trial_started         NaN
# 27      28  2024-08-28T00:00:00        8    subscription_started        4.99
# 28      29  2024-09-27T00:00:00        8    subscription_renewed        4.99
# 29      30  2024-10-16T00:00:00        8  subscription_cancelled         NaN
# 30      31  2024-11-05T00:00:00        9             app_install         NaN
# 31      32  2024-11-10T00:00:00        9           trial_started         NaN
# 32      33  2024-11-21T00:00:00        9    subscription_started        9.99
# 33      34  2024-12-21T00:00:00        9    subscription_renewed        9.99
# 34      35  2024-12-27T00:00:00        9  subscription_cancelled         NaN
# 35      36  2024-04-12T00:00:00       10             app_install         NaN
# 36      37  2024-04-15T00:00:00       10           trial_started         NaN
# 37      38  2024-04-27T00:00:00       10    subscription_started        9.99
# 38      39  2024-05-27T00:00:00       10    subscription_renewed        9.99
# 39      40  2024-06-03T00:00:00       10  subscription_cancelled         NaN
# 40      41  2024-01-12T00:00:00       11             app_install         NaN
# 41      42  2024-01-15T00:00:00       11           trial_started         NaN
# 42      43  2024-01-24T00:00:00       11         trial_cancelled         NaN
# 43      44  2024-01-08T00:00:00       12             app_install         NaN
# 44      45  2024-01-14T00:00:00       12           trial_started         NaN
# 45      46  2024-01-20T00:00:00       12    subscription_started        9.99
# 46      47  2024-02-19T00:00:00       12    subscription_renewed        9.99
# 47      48  2024-03-20T00:00:00       12    subscription_renewed        9.99
# 48      49  2024-04-05T00:00:00       12  subscription_cancelled         NaN
# 49      50  2024-04-10T00:00:00       13             app_install         NaN
# 50      51  2024-04-12T00:00:00       13           trial_started         NaN
# 51      52  2024-04-16T00:00:00       13    subscription_started        4.99
# 52      53  2024-05-16T00:00:00       13    subscription_renewed        4.99
# 53      54  2024-06-15T00:00:00       13    subscription_renewed        4.99
# 54      55  2024-07-15T00:00:00       13    subscription_renewed        4.99
# 55      56  2024-07-24T00:00:00       13  subscription_cancelled         NaN
# 56      57  2024-01-12T00:00:00       14             app_install         NaN
# 57      58  2024-01-18T00:00:00       14           trial_started         NaN
# 58      59  2024-01-30T00:00:00       14    subscription_started        8.99
# 59      60  2024-02-29T00:00:00       14    subscription_renewed        8.99
# 60      61  2024-03-30T00:00:00       14    subscription_renewed        8.99
# 61      62  2024-04-22T00:00:00       14  subscription_cancelled         NaN
# 62      63  2024-07-10T00:00:00       15             app_install         NaN
# 63      64  2024-07-12T00:00:00       15           trial_started         NaN
# 64      65  2024-07-24T00:00:00       15         trial_cancelled         NaN
# 65      66  2024-04-26T00:00:00       16             app_install         NaN
# 66      67  2024-04-28T00:00:00       16           trial_started         NaN
# 67      68  2024-05-02T00:00:00       16    subscription_started        8.99
# 68      69  2024-06-01T00:00:00       16    subscription_renewed        8.99
# 69      70  2024-07-01T00:00:00       16    subscription_renewed        8.99
# 70      71  2024-07-31T00:00:00       16    subscription_renewed        8.99
# 71      72  2024-08-11T00:00:00       16  subscription_cancelled         NaN
# 72      73  2024-04-24T00:00:00       17             app_install         NaN
# 73      74  2024-04-28T00:00:00       17           trial_started         NaN
# 74      75  2024-05-09T00:00:00       17    subscription_started        4.99
# 75      76  2024-06-08T00:00:00       17    subscription_renewed        4.99
# 76      77  2024-07-08T00:00:00       17    subscription_renewed        4.99
# 77      78  2024-08-07T00:00:00       17    subscription_renewed        4.99
# 78      79  2024-09-06T00:00:00       17    subscription_renewed        4.99
# 79      80  2024-09-10T00:00:00       17  subscription_cancelled         NaN
# 80      81  2024-09-19T00:00:00       18             app_install         NaN
# 81      82  2024-10-29T00:00:00       19             app_install         NaN
# 82      83  2024-01-22T00:00:00       20             app_install         NaN
# 83      84  2024-08-10T00:00:00       21             app_install         NaN
# 84      85  2024-03-15T00:00:00       22             app_install         NaN
# 85      86  2024-03-16T00:00:00       22           trial_started         NaN
# 86      87  2024-03-19T00:00:00       22    subscription_started        9.99
# 87      88  2024-04-18T00:00:00       22    subscription_renewed        9.99
# 88      89  2024-05-12T00:00:00       22  subscription_cancelled         NaN
# 89      90  2024-01-24T00:00:00       23             app_install         NaN
# 90      91  2024-05-08T00:00:00       24             app_install         NaN
# 91      92  2024-05-12T00:00:00       24           trial_started         NaN
# 92      93  2024-05-25T00:00:00       24    subscription_started        8.99
# 93      94  2024-06-24T00:00:00       24    subscription_renewed        8.99
# 94      95  2024-07-24T00:00:00       24    subscription_renewed        8.99
# 95      96  2024-08-23T00:00:00       24    subscription_renewed        8.99
# 96      97  2024-09-22T00:00:00       24    subscription_renewed        8.99
# 97      98  2024-10-15T00:00:00       24  subscription_cancelled         NaN
# 98      99  2024-11-15T00:00:00       25             app_install         NaN
# 99     100  2024-11-17T00:00:00       25           trial_started         NaN
# 100    101  2024-11-28T00:00:00       25         trial_cancelled         NaN
# 101    102  2024-02-11T00:00:00       26             app_install         NaN
# 102    103  2024-02-22T00:00:00       27             app_install         NaN
# 103    104  2024-02-27T00:00:00       27           trial_started         NaN
# 104    105  2024-03-11T00:00:00       27    subscription_started        9.99
# 105    106  2025-02-08T00:00:00       28             app_install         NaN
# 106    107  2025-02-12T00:00:00       28           trial_started         NaN
# 107    108  2025-02-18T00:00:00       28    subscription_started        9.99
# 108    109  2025-03-20T00:00:00       28    subscription_renewed        9.99
# 109    110  2025-04-19T00:00:00       28    subscription_renewed        9.99
# 110    111  2025-05-19T00:00:00       28    subscription_renewed        9.99
# 111    112  2025-06-18T00:00:00       28    subscription_renewed        9.99
# 112    113  2025-06-28T00:00:00       28  subscription_cancelled         NaN
# 113    114  2024-11-25T00:00:00       29             app_install         NaN
# 114    115  2024-04-17T00:00:00       30             app_install         NaN
# 115    116  2024-04-18T00:00:00       30           trial_started         NaN
# 116    117  2024-04-30T00:00:00       30         trial_cancelled         NaN
# 117    118  2024-10-08T00:00:00       31             app_install         NaN
# 118    119  2024-10-13T00:00:00       31           trial_started         NaN
# 119    120  2024-10-22T00:00:00       31         trial_cancelled         NaN
# 120    121  2024-02-05T00:00:00       32             app_install         NaN
# 121    122  2024-02-11T00:00:00       32           trial_started         NaN
# 122    123  2024-02-12T00:00:00       32         trial_cancelled         NaN
# 123    124  2025-01-27T00:00:00       33             app_install         NaN
# 124    125  2024-06-05T00:00:00       34             app_install         NaN
# 125    126  2024-06-11T00:00:00       34           trial_started         NaN
# 126    127  2024-06-13T00:00:00       34         trial_cancelled         NaN
# 127    128  2024-07-21T00:00:00       35             app_install         NaN
# 128    129  2024-07-26T00:00:00       35           trial_started         NaN
# 129    130  2024-08-04T00:00:00       35    subscription_started        8.99
# 130    131  2024-09-03T00:00:00       35    subscription_renewed        8.99
# 131    132  2024-10-03T00:00:00       35    subscription_renewed        8.99
# 132    133  2024-10-04T00:00:00       35  subscription_cancelled         NaN
# 133    134  2024-03-14T00:00:00       36             app_install         NaN
# 134    135  2024-03-18T00:00:00       36           trial_started         NaN
# 135    136  2024-03-30T00:00:00       36    subscription_started        4.99
# 136    137  2024-04-29T00:00:00       36    subscription_renewed        4.99
# 137    138  2024-05-29T00:00:00       36    subscription_renewed        4.99
# 138    139  2024-06-28T00:00:00       36    subscription_renewed        4.99
# 139    140  2024-07-28T00:00:00       36    subscription_renewed        4.99
# 140    141  2024-08-21T00:00:00       36  subscription_cancelled         NaN
# 141    142  2024-08-13T00:00:00       37             app_install         NaN
# 142    143  2024-08-18T00:00:00       37           trial_started         NaN
# 143    144  2024-08-21T00:00:00       37    subscription_started        9.99
# 144    145  2024-10-14T00:00:00       38             app_install         NaN
# 145    146  2024-10-18T00:00:00       38           trial_started         NaN
# 146    147  2024-10-19T00:00:00       38    subscription_started        9.99
# 147    148  2024-11-18T00:00:00       38    subscription_renewed        9.99
# 148    149  2024-12-18T00:00:00       38    subscription_renewed        9.99
# 149    150  2025-01-17T00:00:00       38    subscription_renewed        9.99
# 150    151  2025-01-29T00:00:00       38  subscription_cancelled         NaN
# 151    152  2024-05-01T00:00:00       39             app_install         NaN
# 152    153  2024-05-03T00:00:00       39           trial_started         NaN
# 153    154  2024-05-07T00:00:00       39    subscription_started        4.99
# 154    155  2024-05-06T00:00:00       40             app_install         NaN
# 155    156  2024-05-07T00:00:00       40           trial_started         NaN
# 156    157  2024-05-14T00:00:00       40    subscription_started        4.99
# 157    158  2024-06-13T00:00:00       40    subscription_renewed        4.99
# 158    159  2024-07-02T00:00:00       40  subscription_cancelled         NaN
# 159    160  2024-07-06T00:00:00       41             app_install         NaN
# 160    161  2024-07-10T00:00:00       41           trial_started         NaN
# 161    162  2024-07-14T00:00:00       41    subscription_started        4.99
# 162    163  2024-08-13T00:00:00       41    subscription_renewed        4.99
# 163    164  2024-08-15T00:00:00       41  subscription_cancelled         NaN
# 164    165  2024-01-29T00:00:00       42             app_install         NaN
# 165    166  2024-04-28T00:00:00       43             app_install         NaN
# 166    167  2024-06-15T00:00:00       44             app_install         NaN
# 167    168  2024-10-10T00:00:00       45             app_install         NaN
# 168    169  2024-05-15T00:00:00       46             app_install         NaN
# 169    170  2024-05-20T00:00:00       46           trial_started         NaN
# 170    171  2024-05-28T00:00:00       46    subscription_started        8.99
# 171    172  2024-06-27T00:00:00       46    subscription_renewed        8.99
# 172    173  2024-06-30T00:00:00       46  subscription_cancelled         NaN
# 173    174  2024-10-08T00:00:00       47             app_install         NaN
# 174    175  2024-05-04T00:00:00       48             app_install         NaN
# 175    176  2024-05-06T00:00:00       48           trial_started         NaN
# 176    177  2024-05-15T00:00:00       48    subscription_started        9.99
# 177    178  2024-05-14T00:00:00       49             app_install         NaN
# 178    179  2024-11-09T00:00:00       50             app_install         NaN
# 179    180  2024-11-14T00:00:00       50           trial_started         NaN
# 180    181  2024-11-18T00:00:00       50    subscription_started        8.99
# 181    182  2024-12-18T00:00:00       50    subscription_renewed        8.99
# 182    183  2025-01-17T00:00:00       50    subscription_renewed        8.99
# 183    184  2025-02-16T00:00:00       50    subscription_renewed        8.99
# 184    185  2025-03-05T00:00:00       50  subscription_cancelled         NaN
# 185    186  2024-05-26T00:00:00       51             app_install         NaN
# 186    187  2024-07-16T00:00:00       52             app_install         NaN
# 187    188  2024-07-22T00:00:00       52           trial_started         NaN
# 188    189  2024-07-30T00:00:00       52    subscription_started        8.99
# 189    190  2024-08-29T00:00:00       52    subscription_renewed        8.99
# 190    191  2024-09-28T00:00:00       52    subscription_renewed        8.99
# 191    192  2024-10-13T00:00:00       52  subscription_cancelled         NaN
# 192    193  2024-10-24T00:00:00       53             app_install         NaN
# 193    194  2024-03-05T00:00:00       54             app_install         NaN
# 194    195  2024-03-06T00:00:00       54           trial_started         NaN
# 195    196  2024-03-11T00:00:00       54    subscription_started        8.99
# 196    197  2024-04-10T00:00:00       54    subscription_renewed        8.99
# 197    198  2024-04-28T00:00:00       54  subscription_cancelled         NaN
# 198    199  2025-02-10T00:00:00       55             app_install         NaN
# 199    200  2025-02-12T00:00:00       55           trial_started         NaN
# 200    201  2025-02-17T00:00:00       55    subscription_started        4.99
# 201    202  2025-03-19T00:00:00       55    subscription_renewed        4.99
# 202    203  2025-04-18T00:00:00       55    subscription_renewed        4.99
# 203    204  2025-05-18T00:00:00       55    subscription_renewed        4.99
# 204    205  2025-06-04T00:00:00       55  subscription_cancelled         NaN
# 205    206  2024-10-24T00:00:00       56             app_install         NaN
# 206    207  2025-02-10T00:00:00       57             app_install         NaN
# 207    208  2025-02-11T00:00:00       57           trial_started         NaN
# 208    209  2025-02-13T00:00:00       57    subscription_started        4.99
# 209    210  2025-03-15T00:00:00       57    subscription_renewed        4.99
# 210    211  2025-04-14T00:00:00       57    subscription_renewed        4.99
# 211    212  2025-05-01T00:00:00       57  subscription_cancelled         NaN
# 212    213  2024-05-03T00:00:00       58             app_install         NaN
# 213    214  2024-05-07T00:00:00       58           trial_started         NaN
# 214    215  2024-05-18T00:00:00       58         trial_cancelled         NaN
# 215    216  2024-06-20T00:00:00       59             app_install         NaN
# 216    217  2024-06-26T00:00:00       59           trial_started         NaN
# 217    218  2024-07-06T00:00:00       59    subscription_started        8.99
# 218    219  2024-08-07T00:00:00       60             app_install         NaN
# 219    220  2024-08-10T00:00:00       60           trial_started         NaN
# 220    221  2024-08-18T00:00:00       60         trial_cancelled         NaN
# 221    222  2024-12-15T00:00:00       61             app_install         NaN
# 222    223  2024-12-18T00:00:00       61           trial_started         NaN
# 223    224  2024-12-21T00:00:00       61    subscription_started        9.99
# 224    225  2024-07-07T00:00:00       62             app_install         NaN
# 225    226  2025-02-09T00:00:00       63             app_install         NaN
# 226    227  2025-02-13T00:00:00       63           trial_started         NaN
# 227    228  2025-02-16T00:00:00       63    subscription_started        4.99
# 228    229  2025-03-18T00:00:00       63    subscription_renewed        4.99
# 229    230  2025-03-26T00:00:00       63  subscription_cancelled         NaN
# 230    231  2025-01-31T00:00:00       64             app_install         NaN
# 231    232  2025-02-01T00:00:00       64           trial_started         NaN
# 232    233  2025-02-07T00:00:00       64    subscription_started        9.99
# 233    234  2024-04-29T00:00:00       65             app_install         NaN
# 234    235  2024-11-03T00:00:00       66             app_install         NaN
# 235    236  2024-06-18T00:00:00       67             app_install         NaN
# 236    237  2024-07-15T00:00:00       68             app_install         NaN
# 237    238  2024-07-19T00:00:00       68           trial_started         NaN
# 238    239  2024-07-30T00:00:00       68    subscription_started        8.99
# 239    240  2024-11-13T00:00:00       69             app_install         NaN
# 240    241  2024-10-21T00:00:00       70             app_install         NaN
# 241    242  2024-08-05T00:00:00       71             app_install         NaN
# 242    243  2024-12-24T00:00:00       72             app_install         NaN
# 243    244  2024-12-27T00:00:00       72           trial_started         NaN
# 244    245  2025-01-02T00:00:00       72    subscription_started        8.99
# 245    246  2024-02-15T00:00:00       73             app_install         NaN
# 246    247  2024-02-20T00:00:00       73           trial_started         NaN
# 247    248  2024-03-02T00:00:00       73    subscription_started        9.99
# 248    249  2024-04-01T00:00:00       73    subscription_renewed        9.99
# 249    250  2024-05-01T00:00:00       73    subscription_renewed        9.99
# 250    251  2024-05-30T00:00:00       73  subscription_cancelled         NaN
# 251    252  2024-09-30T00:00:00       74             app_install         NaN
# 252    253  2024-10-04T00:00:00       74           trial_started         NaN
# 253    254  2024-10-17T00:00:00       74    subscription_started        8.99
# 254    255  2024-03-25T00:00:00       75             app_install         NaN
# 255    256  2024-03-28T00:00:00       75           trial_started         NaN
# 256    257  2024-04-02T00:00:00       75    subscription_started        4.99
# 257    258  2024-05-02T00:00:00       75    subscription_renewed        4.99
# 258    259  2024-06-01T00:00:00       75    subscription_renewed        4.99
# 259    260  2024-07-01T00:00:00       75    subscription_renewed        4.99
# 260    261  2024-07-19T00:00:00       75  subscription_cancelled         NaN
# 261    262  2024-07-01T00:00:00       76             app_install         NaN
# 262    263  2024-07-02T00:00:00       76           trial_started         NaN
# 263    264  2024-07-10T00:00:00       76    subscription_started        4.99
# 264    265  2024-08-09T00:00:00       76    subscription_renewed        4.99
# 265    266  2024-09-08T00:00:00       76    subscription_renewed        4.99
# 266    267  2024-09-15T00:00:00       76  subscription_cancelled         NaN
# 267    268  2025-01-05T00:00:00       77             app_install         NaN
# 268    269  2025-01-07T00:00:00       77           trial_started         NaN
# 269    270  2025-01-14T00:00:00       77         trial_cancelled         NaN
# 270    271  2024-10-24T00:00:00       78             app_install         NaN
# 271    272  2024-08-22T00:00:00       79             app_install         NaN
# 272    273  2025-01-05T00:00:00       80             app_install         NaN
# 273    274  2024-02-26T00:00:00       81             app_install         NaN
# 274    275  2024-10-28T00:00:00       82             app_install         NaN
# 275    276  2024-10-09T00:00:00       83             app_install         NaN
# 276    277  2024-10-11T00:00:00       83           trial_started         NaN
# 277    278  2024-10-15T00:00:00       83    subscription_started        4.99
# 278    279  2024-11-14T00:00:00       83    subscription_renewed        4.99
# 279    280  2024-12-14T00:00:00       83    subscription_renewed        4.99
# 280    281  2024-12-28T00:00:00       83  subscription_cancelled         NaN
# 281    282  2024-12-26T00:00:00       84             app_install         NaN
# 282    283  2024-10-10T00:00:00       85             app_install         NaN
# 283    284  2024-10-15T00:00:00       85           trial_started         NaN
# 284    285  2024-10-26T00:00:00       85    subscription_started        4.99
# 285    286  2024-11-25T00:00:00       85    subscription_renewed        4.99
# 286    287  2024-12-21T00:00:00       85  subscription_cancelled         NaN
# 287    288  2024-11-29T00:00:00       86             app_install         NaN
# 288    289  2024-12-02T00:00:00       86           trial_started         NaN
# 289    290  2024-12-05T00:00:00       86    subscription_started        4.99
# 290    291  2024-02-01T00:00:00       87             app_install         NaN
# 291    292  2024-06-19T00:00:00       88             app_install         NaN
# 292    293  2024-06-30T00:00:00       89             app_install         NaN
# 293    294  2024-07-02T00:00:00       89           trial_started         NaN
# 294    295  2024-07-08T00:00:00       89    subscription_started        4.99
# 295    296  2024-08-07T00:00:00       89    subscription_renewed        4.99
# 296    297  2024-09-06T00:00:00       89    subscription_renewed        4.99
# 297    298  2024-09-13T00:00:00       89  subscription_cancelled         NaN
# 298    299  2024-09-22T00:00:00       90             app_install         NaN
# 299    300  2024-09-25T00:00:00       90           trial_started         NaN
# 300    301  2024-10-01T00:00:00       90    subscription_started        4.99
# 301    302  2024-10-31T00:00:00       90    subscription_renewed        4.99
# 302    303  2024-11-16T00:00:00       90  subscription_cancelled         NaN
# 303    304  2024-09-17T00:00:00       91             app_install         NaN
# 304    305  2025-02-09T00:00:00       92             app_install         NaN
# 305    306  2025-02-13T00:00:00       92           trial_started         NaN
# 306    307  2025-02-26T00:00:00       92         trial_cancelled         NaN
# 307    308  2024-01-20T00:00:00       93             app_install         NaN
# 308    309  2024-01-21T00:00:00       93           trial_started         NaN
# 309    310  2024-01-25T00:00:00       93    subscription_started        8.99
# 310    311  2024-10-14T00:00:00       94             app_install         NaN
# 311    312  2025-01-26T00:00:00       95             app_install         NaN
# 312    313  2025-01-29T00:00:00       95           trial_started         NaN
# 313    314  2025-02-10T00:00:00       95    subscription_started        9.99
# 314    315  2025-03-12T00:00:00       95    subscription_renewed        9.99
# 315    316  2025-03-19T00:00:00       95  subscription_cancelled         NaN
# 316    317  2024-03-17T00:00:00       96             app_install         NaN
# 317    318  2024-03-23T00:00:00       96           trial_started         NaN
# 318    319  2024-03-31T00:00:00       96    subscription_started        4.99
# 319    320  2024-04-30T00:00:00       96    subscription_renewed        4.99
# 320    321  2024-05-20T00:00:00       96  subscription_cancelled         NaN
# 321    322  2024-06-11T00:00:00       97             app_install         NaN
# 322    323  2024-06-16T00:00:00       97           trial_started         NaN
# 323    324  2024-06-21T00:00:00       97    subscription_started        8.99
# 324    325  2024-07-21T00:00:00       97    subscription_renewed        8.99
# 325    326  2024-08-20T00:00:00       97    subscription_renewed        8.99
# 326    327  2024-09-19T00:00:00       97    subscription_renewed        8.99
# 327    328  2024-10-08T00:00:00       97  subscription_cancelled         NaN
# 328    329  2024-10-19T00:00:00       98             app_install         NaN
# 329    330  2024-02-04T00:00:00       99             app_install         NaN
# 330    331  2024-02-09T00:00:00       99           trial_started         NaN
# 331    332  2024-02-20T00:00:00       99    subscription_started        8.99
# 332    333  2024-03-21T00:00:00       99    subscription_renewed        8.99
# 333    334  2024-04-20T00:00:00       99    subscription_renewed        8.99
# 334    335  2024-05-13T00:00:00       99  subscription_cancelled         NaN
# 335    336  2024-04-14T00:00:00      100             app_install         NaN
# 336    337  2024-04-16T00:00:00      100           trial_started         NaN
# 337    338  2024-04-23T00:00:00      100    subscription_started        8.99
# 338    339  2024-01-07T00:00:00      101             app_install         NaN
# 339    340  2024-01-10T00:00:00      101           trial_started         NaN
# 340    341  2024-01-17T00:00:00      101         trial_cancelled         NaN
# 341    342  2024-03-06T00:00:00      102             app_install         NaN
# 342    343  2024-03-07T00:00:00      102           trial_started         NaN
# 343    344  2024-03-14T00:00:00      102    subscription_started        8.99
# 344    345  2024-04-13T00:00:00      102    subscription_renewed        8.99
# 345    346  2024-05-13T00:00:00      102    subscription_renewed        8.99
# 346    347  2024-06-12T00:00:00      102    subscription_renewed        8.99
# 347    348  2024-07-12T00:00:00      102    subscription_renewed        8.99
# 348    349  2024-07-27T00:00:00      102  subscription_cancelled         NaN
# 349    350  2025-01-18T00:00:00      103             app_install         NaN
# 350    351  2025-01-23T00:00:00      103           trial_started         NaN
# 351    352  2025-02-04T00:00:00      103         trial_cancelled         NaN
# 352    353  2024-05-03T00:00:00      104             app_install         NaN
# 353    354  2024-05-04T00:00:00      104           trial_started         NaN
# 354    355  2024-05-14T00:00:00      104         trial_cancelled         NaN
# 355    356  2024-10-22T00:00:00      105             app_install         NaN
# 356    357  2024-10-28T00:00:00      105           trial_started         NaN
# 357    358  2024-11-05T00:00:00      105         trial_cancelled         NaN
# 358    359  2024-10-31T00:00:00      106             app_install         NaN
# 359    360  2024-11-05T00:00:00      106           trial_started         NaN
# 360    361  2024-11-10T00:00:00      106    subscription_started        9.99
# 361    362  2024-05-25T00:00:00      107             app_install         NaN
# 362    363  2024-05-30T00:00:00      107           trial_started         NaN
# 363    364  2024-06-06T00:00:00      107         trial_cancelled         NaN
# 364    365  2025-02-07T00:00:00      108             app_install         NaN
# 365    366  2024-08-29T00:00:00      109             app_install         NaN
# 366    367  2025-02-04T00:00:00      110             app_install         NaN
# 367    368  2025-02-05T00:00:00      110           trial_started         NaN
# 368    369  2025-02-09T00:00:00      110    subscription_started        4.99
# 369    370  2025-03-11T00:00:00      110    subscription_renewed        4.99
# 370    371  2025-04-10T00:00:00      110    subscription_renewed        4.99
# 371    372  2025-05-10T00:00:00      110    subscription_renewed        4.99
# 372    373  2025-05-20T00:00:00      110  subscription_cancelled         NaN
# 373    374  2024-05-07T00:00:00      111             app_install         NaN
# 374    375  2024-03-20T00:00:00      112             app_install         NaN
# 375    376  2024-03-22T00:00:00      112           trial_started         NaN
# 376    377  2024-04-04T00:00:00      112         trial_cancelled         NaN
# 377    378  2024-06-24T00:00:00      113             app_install         NaN
# 378    379  2024-06-25T00:00:00      113           trial_started         NaN
# 379    380  2024-07-06T00:00:00      113    subscription_started        9.99
# 380    381  2024-08-05T00:00:00      113    subscription_renewed        9.99
# 381    382  2024-09-04T00:00:00      113    subscription_renewed        9.99
# 382    383  2024-09-06T00:00:00      113  subscription_cancelled         NaN
# 383    384  2024-04-23T00:00:00      114             app_install         NaN
# 384    385  2024-04-27T00:00:00      114           trial_started         NaN
# 385    386  2024-04-30T00:00:00      114         trial_cancelled         NaN
# 386    387  2025-01-12T00:00:00      115             app_install         NaN
# 387    388  2025-01-13T00:00:00      115           trial_started         NaN
# 388    389  2025-01-16T00:00:00      115    subscription_started        4.99
# 389    390  2025-02-15T00:00:00      115    subscription_renewed        4.99
# 390    391  2025-03-15T00:00:00      115  subscription_cancelled         NaN
# 391    392  2024-10-24T00:00:00      116             app_install         NaN
# 392    393  2024-10-30T00:00:00      116           trial_started         NaN
# 393    394  2024-11-08T00:00:00      116    subscription_started        9.99
# 394    395  2024-12-08T00:00:00      116    subscription_renewed        9.99
# 395    396  2024-12-27T00:00:00      116  subscription_cancelled         NaN
# 396    397  2024-05-21T00:00:00      117             app_install         NaN
# 397    398  2024-05-25T00:00:00      117           trial_started         NaN
# 398    399  2024-06-03T00:00:00      117    subscription_started        9.99
# 399    400  2024-07-03T00:00:00      117    subscription_renewed        9.99
# 400    401  2024-08-02T00:00:00      117    subscription_renewed        9.99
# 401    402  2024-08-18T00:00:00      117  subscription_cancelled         NaN
# 402    403  2024-10-23T00:00:00      118             app_install         NaN
# 403    404  2024-10-25T00:00:00      118           trial_started         NaN
# 404    405  2024-11-04T00:00:00      118    subscription_started        4.99
# 405    406  2024-08-21T00:00:00      119             app_install         NaN
# 406    407  2024-08-26T00:00:00      119           trial_started         NaN
# 407    408  2024-09-02T00:00:00      119    subscription_started        4.99
# 408    409  2024-10-02T00:00:00      119    subscription_renewed        4.99
# 409    410  2024-11-01T00:00:00      119    subscription_renewed        4.99
# 410    411  2024-12-01T00:00:00      119    subscription_renewed        4.99
# 411    412  2024-12-20T00:00:00      119  subscription_cancelled         NaN
# 412    413  2024-05-07T00:00:00      120             app_install         NaN
# 413    414  2024-06-26T00:00:00      121             app_install         NaN
# 414    415  2024-10-04T00:00:00      122             app_install         NaN
# 415    416  2024-12-23T00:00:00      123             app_install         NaN
# 416    417  2024-04-11T00:00:00      124             app_install         NaN
# 417    418  2024-04-14T00:00:00      124           trial_started         NaN
# 418    419  2024-04-21T00:00:00      124    subscription_started        8.99
# 419    420  2024-04-21T00:00:00      125             app_install         NaN
# 420    421  2024-09-26T00:00:00      126             app_install         NaN
# 421    422  2024-09-27T00:00:00      126           trial_started         NaN
# 422    423  2024-10-07T00:00:00      126    subscription_started        9.99
# 423    424  2024-11-06T00:00:00      126    subscription_renewed        9.99
# 424    425  2024-12-06T00:00:00      126    subscription_renewed        9.99
# 425    426  2025-01-05T00:00:00      126    subscription_renewed        9.99
# 426    427  2025-01-26T00:00:00      126  subscription_cancelled         NaN
# 427    428  2024-06-10T00:00:00      127             app_install         NaN
# 428    429  2024-07-06T00:00:00      128             app_install         NaN
# 429    430  2024-07-11T00:00:00      128           trial_started         NaN
# 430    431  2024-07-20T00:00:00      128         trial_cancelled         NaN
# 431    432  2024-04-08T00:00:00      129             app_install         NaN
# 432    433  2024-09-09T00:00:00      130             app_install         NaN
# 433    434  2024-09-13T00:00:00      130           trial_started         NaN
# 434    435  2024-09-21T00:00:00      130         trial_cancelled         NaN
# 435    436  2024-10-24T00:00:00      131             app_install         NaN
# 436    437  2024-01-02T00:00:00      132             app_install         NaN
# 437    438  2024-01-04T00:00:00      132           trial_started         NaN
# 438    439  2024-01-17T00:00:00      132    subscription_started        8.99
# 439    440  2024-02-16T00:00:00      132    subscription_renewed        8.99
# 440    441  2024-03-17T00:00:00      132    subscription_renewed        8.99
# 441    442  2024-04-11T00:00:00      132  subscription_cancelled         NaN
# 442    443  2024-08-27T00:00:00      133             app_install         NaN
# 443    444  2024-08-30T00:00:00      133           trial_started         NaN
# 444    445  2024-09-11T00:00:00      133    subscription_started        9.99
# 445    446  2024-10-11T00:00:00      133    subscription_renewed        9.99
# 446    447  2024-11-10T00:00:00      133    subscription_renewed        9.99
# 447    448  2024-12-10T00:00:00      133    subscription_renewed        9.99
# 448    449  2024-12-17T00:00:00      133  subscription_cancelled         NaN
# 449    450  2024-07-03T00:00:00      134             app_install         NaN
# 450    451  2024-07-08T00:00:00      134           trial_started         NaN
# 451    452  2024-07-17T00:00:00      134         trial_cancelled         NaN
# 452    453  2024-09-15T00:00:00      135             app_install         NaN
# 453    454  2024-09-16T00:00:00      135           trial_started         NaN
# 454    455  2024-09-21T00:00:00      135    subscription_started        4.99
# 455    456  2024-10-21T00:00:00      135    subscription_renewed        4.99
# 456    457  2024-11-20T00:00:00      135    subscription_renewed        4.99
# 457    458  2024-12-04T00:00:00      135  subscription_cancelled         NaN
# 458    459  2024-03-13T00:00:00      136             app_install         NaN
# 459    460  2024-03-10T00:00:00      137             app_install         NaN
# 460    461  2024-07-08T00:00:00      138             app_install         NaN
# 461    462  2024-07-11T00:00:00      138           trial_started         NaN
# 462    463  2024-07-24T00:00:00      138    subscription_started        9.99
# 463    464  2024-08-23T00:00:00      138    subscription_renewed        9.99
# 464    465  2024-09-05T00:00:00      138  subscription_cancelled         NaN
# 465    466  2024-10-14T00:00:00      139             app_install         NaN
# 466    467  2024-10-18T00:00:00      139           trial_started         NaN
# 467    468  2024-10-25T00:00:00      139    subscription_started        8.99
# 468    469  2024-11-24T00:00:00      139    subscription_renewed        8.99
# 469    470  2024-12-24T00:00:00      139    subscription_renewed        8.99
# 470    471  2025-01-23T00:00:00      139    subscription_renewed        8.99
# 471    472  2025-02-06T00:00:00      139  subscription_cancelled         NaN
# 472    473  2025-02-03T00:00:00      140             app_install         NaN
# 473    474  2024-07-23T00:00:00      141             app_install         NaN
# 474    475  2024-06-25T00:00:00      142             app_install         NaN
# 475    476  2024-01-13T00:00:00      143             app_install         NaN
# 476    477  2024-03-23T00:00:00      144             app_install         NaN
# 477    478  2024-03-27T00:00:00      144           trial_started         NaN
# 478    479  2024-04-09T00:00:00      144    subscription_started        9.99
# 479    480  2024-05-09T00:00:00      144    subscription_renewed        9.99
# 480    481  2024-06-08T00:00:00      144    subscription_renewed        9.99
# 481    482  2024-06-26T00:00:00      144  subscription_cancelled         NaN
# 482    483  2024-03-25T00:00:00      145             app_install         NaN
# 483    484  2024-03-31T00:00:00      145           trial_started         NaN
# 484    485  2024-04-06T00:00:00      145    subscription_started        8.99
# 485    486  2024-05-06T00:00:00      145    subscription_renewed        8.99
# 486    487  2024-05-29T00:00:00      145  subscription_cancelled         NaN
# 487    488  2024-10-10T00:00:00      146             app_install         NaN
# 488    489  2024-10-11T00:00:00      146           trial_started         NaN
# 489    490  2024-10-22T00:00:00      146    subscription_started        8.99
# 490    491  2024-01-24T00:00:00      147             app_install         NaN
# 491    492  2025-02-14T00:00:00      148             app_install         NaN
# 492    493  2024-03-21T00:00:00      149             app_install         NaN
# 493    494  2024-03-24T00:00:00      149           trial_started         NaN
# 494    495  2024-03-31T00:00:00      149    subscription_started        4.99
# 495    496  2024-10-29T00:00:00      150             app_install         NaN
# 496    497  2024-01-24T00:00:00      151             app_install         NaN
# 497    498  2024-11-11T00:00:00      152             app_install         NaN
# 498    499  2024-11-12T00:00:00      152           trial_started         NaN
# 499    500  2024-11-20T00:00:00      152    subscription_started        9.99
# 500    501  2024-12-20T00:00:00      152    subscription_renewed        9.99
# 501    502  2025-01-08T00:00:00      152  subscription_cancelled         NaN
# 502    503  2024-07-08T00:00:00      153             app_install         NaN
# 503    504  2024-07-13T00:00:00      153           trial_started         NaN
# 504    505  2024-07-21T00:00:00      153    subscription_started        9.99
# 505    506  2024-08-20T00:00:00      153    subscription_renewed        9.99
# 506    507  2024-09-18T00:00:00      153  subscription_cancelled         NaN
# 507    508  2024-09-17T00:00:00      154             app_install         NaN
# 508    509  2024-09-22T00:00:00      154           trial_started         NaN
# 509    510  2024-10-05T00:00:00      154    subscription_started        4.99
# 510    511  2024-11-04T00:00:00      154    subscription_renewed        4.99
# 511    512  2024-12-04T00:00:00      154    subscription_renewed        4.99
# 512    513  2024-12-27T00:00:00      154  subscription_cancelled         NaN
# 513    514  2025-01-31T00:00:00      155             app_install         NaN
# 514    515  2024-07-04T00:00:00      156             app_install         NaN
# 515    516  2024-08-15T00:00:00      157             app_install         NaN
# 516    517  2024-07-11T00:00:00      158             app_install         NaN
# 517    518  2024-07-17T00:00:00      158           trial_started         NaN
# 518    519  2024-07-22T00:00:00      158    subscription_started        8.99
# 519    520  2024-08-21T00:00:00      158    subscription_renewed        8.99
# 520    521  2024-09-20T00:00:00      158    subscription_renewed        8.99
# 521    522  2024-10-20T00:00:00      158    subscription_renewed        8.99
# 522    523  2024-11-19T00:00:00      158    subscription_renewed        8.99
# 523    524  2024-12-01T00:00:00      158  subscription_cancelled         NaN
# 524    525  2024-08-20T00:00:00      159             app_install         NaN
# 525    526  2024-08-24T00:00:00      159           trial_started         NaN
# 526    527  2024-08-29T00:00:00      159    subscription_started        4.99
# 527    528  2024-04-07T00:00:00      160             app_install         NaN
# 528    529  2024-04-10T00:00:00      160           trial_started         NaN
# 529    530  2024-04-21T00:00:00      160    subscription_started        8.99
# 530    531  2024-03-01T00:00:00      161             app_install         NaN
# 531    532  2024-03-03T00:00:00      161           trial_started         NaN
# 532    533  2024-03-04T00:00:00      161    subscription_started        4.99
# 533    534  2024-04-03T00:00:00      161    subscription_renewed        4.99
# 534    535  2024-05-03T00:00:00      161    subscription_renewed        4.99
# 535    536  2024-05-24T00:00:00      161  subscription_cancelled         NaN
# 536    537  2024-05-17T00:00:00      162             app_install         NaN
# 537    538  2024-05-22T00:00:00      162           trial_started         NaN
# 538    539  2024-06-04T00:00:00      162    subscription_started        9.99
# 539    540  2024-07-04T00:00:00      162    subscription_renewed        9.99
# 540    541  2024-08-03T00:00:00      162    subscription_renewed        9.99
# 541    542  2024-08-11T00:00:00      162  subscription_cancelled         NaN
# 542    543  2024-05-17T00:00:00      163             app_install         NaN
# 543    544  2024-05-30T00:00:00      164             app_install         NaN
# 544    545  2024-06-05T00:00:00      164           trial_started         NaN
# 545    546  2024-06-15T00:00:00      164    subscription_started        4.99
# 546    547  2024-07-15T00:00:00      164    subscription_renewed        4.99
# 547    548  2024-07-25T00:00:00      164  subscription_cancelled         NaN
# 548    549  2024-11-18T00:00:00      165             app_install         NaN
# 549    550  2024-11-24T00:00:00      165           trial_started         NaN
# 550    551  2024-11-28T00:00:00      165         trial_cancelled         NaN
# 551    552  2024-10-20T00:00:00      166             app_install         NaN
# 552    553  2024-10-22T00:00:00      166           trial_started         NaN
# 553    554  2024-11-03T00:00:00      166    subscription_started        4.99
# 554    555  2024-12-03T00:00:00      166    subscription_renewed        4.99
# 555    556  2025-01-02T00:00:00      166    subscription_renewed        4.99
# 556    557  2025-01-19T00:00:00      166  subscription_cancelled         NaN
# 557    558  2024-04-23T00:00:00      167             app_install         NaN
# 558    559  2024-04-28T00:00:00      167           trial_started         NaN
# 559    560  2024-05-07T00:00:00      167    subscription_started        8.99
# 560    561  2024-06-06T00:00:00      167    subscription_renewed        8.99
# 561    562  2024-06-25T00:00:00      167  subscription_cancelled         NaN
# 562    563  2024-07-15T00:00:00      168             app_install         NaN
# 563    564  2024-07-18T00:00:00      168           trial_started         NaN
# 564    565  2024-07-23T00:00:00      168         trial_cancelled         NaN
# 565    566  2024-04-13T00:00:00      169             app_install         NaN
# 566    567  2024-04-16T00:00:00      169           trial_started         NaN
# 567    568  2024-04-17T00:00:00      169    subscription_started        4.99
# 568    569  2024-05-17T00:00:00      169    subscription_renewed        4.99
# 569    570  2024-06-16T00:00:00      169    subscription_renewed        4.99
# 570    571  2024-07-06T00:00:00      169  subscription_cancelled         NaN
# 571    572  2024-11-13T00:00:00      170             app_install         NaN
# 572    573  2024-10-22T00:00:00      171             app_install         NaN
# 573    574  2024-02-19T00:00:00      172             app_install         NaN
# 574    575  2024-02-25T00:00:00      172           trial_started         NaN
# 575    576  2024-03-01T00:00:00      172    subscription_started        8.99
# 576    577  2024-10-23T00:00:00      173             app_install         NaN
# 577    578  2024-11-20T00:00:00      174             app_install         NaN
# 578    579  2024-11-22T00:00:00      174           trial_started         NaN
# 579    580  2024-11-23T00:00:00      174    subscription_started        8.99
# 580    581  2024-12-06T00:00:00      175             app_install         NaN
# 581    582  2024-12-11T00:00:00      175           trial_started         NaN
# 582    583  2024-12-14T00:00:00      175    subscription_started        8.99
# 583    584  2025-01-13T00:00:00      175    subscription_renewed        8.99
# 584    585  2025-02-12T00:00:00      175    subscription_renewed        8.99
# 585    586  2025-03-14T00:00:00      175    subscription_renewed        8.99
# 586    587  2025-03-17T00:00:00      175  subscription_cancelled         NaN
# 587    588  2025-01-07T00:00:00      176             app_install         NaN
# 588    589  2025-01-10T00:00:00      176           trial_started         NaN
# 589    590  2025-01-18T00:00:00      176    subscription_started        4.99
# 590    591  2024-01-29T00:00:00      177             app_install         NaN
# 591    592  2024-02-04T00:00:00      177           trial_started         NaN
# 592    593  2024-02-09T00:00:00      177    subscription_started        8.99
# 593    594  2024-03-10T00:00:00      177    subscription_renewed        8.99
# 594    595  2024-04-07T00:00:00      177  subscription_cancelled         NaN
# 595    596  2024-02-25T00:00:00      178             app_install         NaN
# 596    597  2024-04-04T00:00:00      179             app_install         NaN
# 597    598  2024-04-08T00:00:00      179           trial_started         NaN
# 598    599  2024-04-15T00:00:00      179    subscription_started        9.99
# 599    600  2024-05-15T00:00:00      179    subscription_renewed        9.99
# 600    601  2024-06-14T00:00:00      179    subscription_renewed        9.99
# 601    602  2024-07-14T00:00:00      179    subscription_renewed        9.99
# 602    603  2024-08-05T00:00:00      179  subscription_cancelled         NaN
# 603    604  2024-11-23T00:00:00      180             app_install         NaN
# 604    605  2024-02-19T00:00:00      181             app_install         NaN
# 605    606  2024-02-20T00:00:00      181           trial_started         NaN
# 606    607  2024-03-03T00:00:00      181    subscription_started        4.99
# 607    608  2024-06-14T00:00:00      182             app_install         NaN
# 608    609  2024-02-10T00:00:00      183             app_install         NaN
# 609    610  2024-02-14T00:00:00      183           trial_started         NaN
# 610    611  2024-02-24T00:00:00      183    subscription_started        8.99
# 611    612  2024-04-30T00:00:00      184             app_install         NaN
# 612    613  2024-05-04T00:00:00      184           trial_started         NaN
# 613    614  2024-05-12T00:00:00      184         trial_cancelled         NaN
# 614    615  2024-12-30T00:00:00      185             app_install         NaN
# 615    616  2025-01-05T00:00:00      185           trial_started         NaN
# 616    617  2025-01-12T00:00:00      185    subscription_started        8.99
# 617    618  2024-07-16T00:00:00      186             app_install         NaN
# 618    619  2024-07-20T00:00:00      186           trial_started         NaN
# 619    620  2024-07-26T00:00:00      186    subscription_started        8.99
# 620    621  2024-06-14T00:00:00      187             app_install         NaN
# 621    622  2025-01-02T00:00:00      188             app_install         NaN
# ...
# 3279  3280  2024-03-23T00:00:00      943           trial_started         NaN
# 3280  3281  2024-03-27T00:00:00      943         trial_cancelled         NaN
# 3281  3282  2024-06-12T00:00:00      944             app_install         NaN
# 3282  3283  2024-06-17T00:00:00      944           trial_started         NaN
# 3283  3284  2024-06-22T00:00:00      944         trial_cancelled         NaN
# 3284  3285  2024-12-27T00:00:00      945             app_install         NaN
# 3285  3286  2024-12-28T00:00:00      945           trial_started         NaN
# 3286  3287  2024-12-29T00:00:00      945         trial_cancelled         NaN
# 3287  3288  2024-08-15T00:00:00      946             app_install         NaN
# 3288  3289  2024-01-05T00:00:00      947             app_install         NaN
# 3289  3290  2024-01-09T00:00:00      947           trial_started         NaN
# 3290  3291  2024-01-21T00:00:00      947         trial_cancelled         NaN
# 3291  3292  2024-10-16T00:00:00      948             app_install         NaN
# 3292  3293  2024-10-21T00:00:00      948           trial_started         NaN
# 3293  3294  2024-10-30T00:00:00      948    subscription_started        4.99
# 3294  3295  2024-11-29T00:00:00      948    subscription_renewed        4.99
# 3295  3296  2024-12-29T00:00:00      948    subscription_renewed        4.99
# 3296  3297  2025-01-28T00:00:00      948    subscription_renewed        4.99
# 3297  3298  2025-02-04T00:00:00      948  subscription_cancelled         NaN
# 3298  3299  2024-09-25T00:00:00      949             app_install         NaN
# 3299  3300  2024-09-30T00:00:00      949           trial_started         NaN
# 3300  3301  2024-10-01T00:00:00      949         trial_cancelled         NaN
# 3301  3302  2025-02-07T00:00:00      950             app_install         NaN
# 3302  3303  2025-02-12T00:00:00      950           trial_started         NaN
# 3303  3304  2025-02-23T00:00:00      950    subscription_started        4.99
# 3304  3305  2025-03-25T00:00:00      950    subscription_renewed        4.99
# 3305  3306  2025-04-24T00:00:00      950    subscription_renewed        4.99
# 3306  3307  2025-05-24T00:00:00      950    subscription_renewed        4.99
# 3307  3308  2025-06-23T00:00:00      950    subscription_renewed        4.99
# 3308  3309  2025-06-24T00:00:00      950  subscription_cancelled         NaN
# 3309  3310  2024-06-30T00:00:00      951             app_install         NaN
# 3310  3311  2024-07-04T00:00:00      951           trial_started         NaN
# 3311  3312  2024-07-12T00:00:00      951         trial_cancelled         NaN
# 3312  3313  2024-02-13T00:00:00      952             app_install         NaN
# 3313  3314  2024-04-12T00:00:00      953             app_install         NaN
# 3314  3315  2024-04-18T00:00:00      953           trial_started         NaN
# 3315  3316  2024-04-21T00:00:00      953         trial_cancelled         NaN
# 3316  3317  2024-02-05T00:00:00      954             app_install         NaN
# 3317  3318  2024-02-10T00:00:00      954           trial_started         NaN
# 3318  3319  2024-02-14T00:00:00      954    subscription_started        4.99
# 3319  3320  2024-03-15T00:00:00      954    subscription_renewed        4.99
# 3320  3321  2024-04-14T00:00:00      954    subscription_renewed        4.99
# 3321  3322  2024-05-14T00:00:00      954    subscription_renewed        4.99
# 3322  3323  2024-06-13T00:00:00      954    subscription_renewed        4.99
# 3323  3324  2024-07-05T00:00:00      954  subscription_cancelled         NaN
# 3324  3325  2024-07-30T00:00:00      955             app_install         NaN
# 3325  3326  2024-07-31T00:00:00      955           trial_started         NaN
# 3326  3327  2024-08-01T00:00:00      955    subscription_started        4.99
# 3327  3328  2024-08-31T00:00:00      955    subscription_renewed        4.99
# 3328  3329  2024-09-30T00:00:00      955    subscription_renewed        4.99
# 3329  3330  2024-10-08T00:00:00      955  subscription_cancelled         NaN
# 3330  3331  2024-08-06T00:00:00      956             app_install         NaN
# 3331  3332  2024-08-08T00:00:00      956           trial_started         NaN
# 3332  3333  2024-08-15T00:00:00      956         trial_cancelled         NaN
# 3333  3334  2025-01-22T00:00:00      957             app_install         NaN
# 3334  3335  2024-09-16T00:00:00      958             app_install         NaN
# 3335  3336  2024-09-17T00:00:00      958           trial_started         NaN
# 3336  3337  2024-09-23T00:00:00      958         trial_cancelled         NaN
# 3337  3338  2024-01-12T00:00:00      959             app_install         NaN
# 3338  3339  2024-01-13T00:00:00      959           trial_started         NaN
# 3339  3340  2024-01-23T00:00:00      959    subscription_started        8.99
# 3340  3341  2024-02-22T00:00:00      959    subscription_renewed        8.99
# 3341  3342  2024-03-19T00:00:00      959  subscription_cancelled         NaN
# 3342  3343  2024-04-12T00:00:00      960             app_install         NaN
# 3343  3344  2024-09-18T00:00:00      961             app_install         NaN
# 3344  3345  2024-09-21T00:00:00      961           trial_started         NaN
# 3345  3346  2024-10-01T00:00:00      961    subscription_started        4.99
# 3346  3347  2024-10-31T00:00:00      961    subscription_renewed        4.99
# 3347  3348  2024-11-29T00:00:00      961  subscription_cancelled         NaN
# 3348  3349  2024-05-11T00:00:00      962             app_install         NaN
# 3349  3350  2024-05-13T00:00:00      962           trial_started         NaN
# 3350  3351  2024-05-19T00:00:00      962         trial_cancelled         NaN
# 3351  3352  2024-01-01T00:00:00      963             app_install         NaN
# 3352  3353  2024-03-25T00:00:00      964             app_install         NaN
# 3353  3354  2024-03-26T00:00:00      964           trial_started         NaN
# 3354  3355  2024-03-27T00:00:00      964    subscription_started        9.99
# 3355  3356  2024-04-26T00:00:00      964    subscription_renewed        9.99
# 3356  3357  2024-05-26T00:00:00      964    subscription_renewed        9.99
# 3357  3358  2024-06-24T00:00:00      964  subscription_cancelled         NaN
# 3358  3359  2025-02-01T00:00:00      965             app_install         NaN
# 3359  3360  2025-02-04T00:00:00      965           trial_started         NaN
# 3360  3361  2025-02-14T00:00:00      965         trial_cancelled         NaN
# 3361  3362  2024-06-04T00:00:00      966             app_install         NaN
# 3362  3363  2024-06-08T00:00:00      966           trial_started         NaN
# 3363  3364  2024-06-18T00:00:00      966    subscription_started        8.99
# 3364  3365  2024-07-18T00:00:00      966    subscription_renewed        8.99
# 3365  3366  2024-08-04T00:00:00      966  subscription_cancelled         NaN
# 3366  3367  2024-03-17T00:00:00      967             app_install         NaN
# 3367  3368  2024-03-23T00:00:00      967           trial_started         NaN
# 3368  3369  2024-03-31T00:00:00      967    subscription_started        4.99
# 3369  3370  2024-04-30T00:00:00      967    subscription_renewed        4.99
# 3370  3371  2024-05-30T00:00:00      967    subscription_renewed        4.99
# 3371  3372  2024-06-29T00:00:00      967    subscription_renewed        4.99
# 3372  3373  2024-07-16T00:00:00      967  subscription_cancelled         NaN
# 3373  3374  2025-01-28T00:00:00      968             app_install         NaN
# 3374  3375  2024-12-03T00:00:00      969             app_install         NaN
# 3375  3376  2024-08-16T00:00:00      970             app_install         NaN
# 3376  3377  2024-08-19T00:00:00      970           trial_started         NaN
# 3377  3378  2024-08-27T00:00:00      970    subscription_started        8.99
# 3378  3379  2024-09-26T00:00:00      970    subscription_renewed        8.99
# 3379  3380  2024-10-08T00:00:00      970  subscription_cancelled         NaN
# 3380  3381  2025-01-28T00:00:00      971             app_install         NaN
# 3381  3382  2024-08-27T00:00:00      972             app_install         NaN
# 3382  3383  2024-08-29T00:00:00      972           trial_started         NaN
# 3383  3384  2024-08-30T00:00:00      972         trial_cancelled         NaN
# 3384  3385  2024-07-24T00:00:00      973             app_install         NaN
# 3385  3386  2024-05-31T00:00:00      974             app_install         NaN
# 3386  3387  2024-07-22T00:00:00      975             app_install         NaN
# 3387  3388  2024-05-28T00:00:00      976             app_install         NaN
# 3388  3389  2024-12-13T00:00:00      977             app_install         NaN
# 3389  3390  2024-12-17T00:00:00      977           trial_started         NaN
# 3390  3391  2024-12-21T00:00:00      977    subscription_started        4.99
# 3391  3392  2024-10-12T00:00:00      978             app_install         NaN
# 3392  3393  2024-10-17T00:00:00      978           trial_started         NaN
# 3393  3394  2024-10-19T00:00:00      978         trial_cancelled         NaN
# 3394  3395  2025-01-24T00:00:00      979             app_install         NaN
# 3395  3396  2025-01-29T00:00:00      979           trial_started         NaN
# 3396  3397  2025-02-05T00:00:00      979    subscription_started        4.99
# 3397  3398  2025-03-07T00:00:00      979    subscription_renewed        4.99
# 3398  3399  2025-04-06T00:00:00      979    subscription_renewed        4.99
# 3399  3400  2025-05-06T00:00:00      979    subscription_renewed        4.99
# 3400  3401  2025-05-10T00:00:00      979  subscription_cancelled         NaN
# 3401  3402  2024-03-26T00:00:00      980             app_install         NaN
# 3402  3403  2024-04-01T00:00:00      980           trial_started         NaN
# 3403  3404  2024-04-03T00:00:00      980    subscription_started        8.99
# 3404  3405  2024-05-03T00:00:00      980    subscription_renewed        8.99
# 3405  3406  2024-06-02T00:00:00      980    subscription_renewed        8.99
# 3406  3407  2024-06-03T00:00:00      980  subscription_cancelled         NaN
# 3407  3408  2024-04-16T00:00:00      981             app_install         NaN
# 3408  3409  2024-04-20T00:00:00      981           trial_started         NaN
# 3409  3410  2024-04-27T00:00:00      981         trial_cancelled         NaN
# 3410  3411  2024-04-20T00:00:00      982             app_install         NaN
# 3411  3412  2024-04-24T00:00:00      982           trial_started         NaN
# 3412  3413  2024-05-01T00:00:00      982    subscription_started        8.99
# 3413  3414  2024-08-03T00:00:00      983             app_install         NaN
# 3414  3415  2024-08-09T00:00:00      983           trial_started         NaN
# 3415  3416  2024-08-10T00:00:00      983         trial_cancelled         NaN
# 3416  3417  2024-08-24T00:00:00      984             app_install         NaN
# 3417  3418  2024-11-04T00:00:00      985             app_install         NaN
# 3418  3419  2024-11-09T00:00:00      985           trial_started         NaN
# 3419  3420  2024-11-19T00:00:00      985         trial_cancelled         NaN
# 3420  3421  2024-08-27T00:00:00      986             app_install         NaN
# 3421  3422  2024-08-28T00:00:00      986           trial_started         NaN
# 3422  3423  2024-08-30T00:00:00      986    subscription_started        4.99
# 3423  3424  2024-09-29T00:00:00      986    subscription_renewed        4.99
# 3424  3425  2024-10-01T00:00:00      986  subscription_cancelled         NaN
# 3425  3426  2024-10-18T00:00:00      987             app_install         NaN
# 3426  3427  2024-09-05T00:00:00      988             app_install         NaN
# 3427  3428  2024-09-09T00:00:00      988           trial_started         NaN
# 3428  3429  2024-09-11T00:00:00      988    subscription_started        8.99
# 3429  3430  2024-10-11T00:00:00      988    subscription_renewed        8.99
# 3430  3431  2024-10-18T00:00:00      988  subscription_cancelled         NaN
# 3431  3432  2025-01-12T00:00:00      989             app_install         NaN
# 3432  3433  2025-01-17T00:00:00      989           trial_started         NaN
# 3433  3434  2025-01-30T00:00:00      989    subscription_started        8.99
# 3434  3435  2025-03-01T00:00:00      989    subscription_renewed        8.99
# 3435  3436  2025-03-31T00:00:00      989    subscription_renewed        8.99
# 3436  3437  2025-04-08T00:00:00      989  subscription_cancelled         NaN
# 3437  3438  2024-11-24T00:00:00      990             app_install         NaN
# 3438  3439  2024-11-26T00:00:00      990           trial_started         NaN
# 3439  3440  2024-11-29T00:00:00      990    subscription_started        4.99
# 3440  3441  2025-02-12T00:00:00      991             app_install         NaN
# 3441  3442  2025-02-15T00:00:00      991           trial_started         NaN
# 3442  3443  2025-02-27T00:00:00      991    subscription_started        4.99
# 3443  3444  2025-03-29T00:00:00      991    subscription_renewed        4.99
# 3444  3445  2025-04-28T00:00:00      991    subscription_renewed        4.99
# 3445  3446  2025-05-28T00:00:00      991    subscription_renewed        4.99
# 3446  3447  2025-06-22T00:00:00      991  subscription_cancelled         NaN
# 3447  3448  2025-02-07T00:00:00      992             app_install         NaN
# 3448  3449  2025-02-09T00:00:00      992           trial_started         NaN
# 3449  3450  2025-02-10T00:00:00      992    subscription_started        9.99
# 3450  3451  2025-03-12T00:00:00      992    subscription_renewed        9.99
# 3451  3452  2025-04-11T00:00:00      992    subscription_renewed        9.99
# 3452  3453  2025-05-11T00:00:00      992    subscription_renewed        9.99
# 3453  3454  2025-06-10T00:00:00      992    subscription_renewed        9.99
# 3454  3455  2025-06-20T00:00:00      992  subscription_cancelled         NaN
# 3455  3456  2024-05-29T00:00:00      993             app_install         NaN
# 3456  3457  2024-07-23T00:00:00      994             app_install         NaN
# 3457  3458  2024-09-30T00:00:00      995             app_install         NaN
# 3458  3459  2024-10-04T00:00:00      995           trial_started         NaN
# 3459  3460  2024-10-17T00:00:00      995    subscription_started        9.99
# 3460  3461  2024-11-16T00:00:00      995    subscription_renewed        9.99
# 3461  3462  2024-12-16T00:00:00      995    subscription_renewed        9.99
# 3462  3463  2025-01-08T00:00:00      995  subscription_cancelled         NaN
# 3463  3464  2025-01-28T00:00:00      996             app_install         NaN
# 3464  3465  2025-02-01T00:00:00      996           trial_started         NaN
# 3465  3466  2025-02-06T00:00:00      996    subscription_started        4.99
# 3466  3467  2025-03-08T00:00:00      996    subscription_renewed        4.99
# 3467  3468  2025-04-07T00:00:00      996    subscription_renewed        4.99
# 3468  3469  2025-05-03T00:00:00      996  subscription_cancelled         NaN
# 3469  3470  2024-03-06T00:00:00      997             app_install         NaN
# 3470  3471  2024-03-08T00:00:00      997           trial_started         NaN
# 3471  3472  2024-03-16T00:00:00      997         trial_cancelled         NaN
# 3472  3473  2025-02-01T00:00:00      998             app_install         NaN
# 3473  3474  2024-12-24T00:00:00      999             app_install         NaN
# 3474  3475  2024-12-29T00:00:00      999           trial_started         NaN
# 3475  3476  2025-01-03T00:00:00      999    subscription_started        8.99
# 3476  3477  2025-02-02T00:00:00      999    subscription_renewed        8.99
# 3477  3478  2025-03-04T00:00:00      999    subscription_renewed        8.99
# 3478  3479  2025-03-08T00:00:00      999  subscription_cancelled         NaN
# 3479  3480  2025-02-13T00:00:00     1000             app_install         NaN
# 3480  3481  2025-02-15T00:00:00     1000           trial_started         NaN
# 3481  3482  2025-02-25T00:00:00     1000         trial_cancelled         NaN
# 3482  3483  2025-02-25T00:00:00     1001             app_install         NaN
# 3483  3484  2025-02-25T00:00:00     1001           trial_started         NaN
# 3484  3485  2025-02-25T00:00:00     1001    subscription_started        9.99
# 3485  3486  2025-02-25T00:00:00     1002             app_install         NaN

# %%
events_df
# Out:
#         id           created_at  user_id            event_name  amount_usd
# 0        1  2024-05-07T00:00:00        1           app_install         NaN
# 1        2  2024-05-12T00:00:00        1         trial_started         NaN
# 2        3  2024-05-24T00:00:00        1       trial_cancelled         NaN
# 3        4  2024-10-12T00:00:00        2           app_install         NaN
# 4        5  2024-10-13T00:00:00        2         trial_started         NaN
# ...    ...                  ...      ...                   ...         ...
# 3481  3482  2025-02-25T00:00:00     1000       trial_cancelled         NaN
# 3482  3483  2025-02-25T00:00:00     1001           app_install         NaN
# 3483  3484  2025-02-25T00:00:00     1001         trial_started         NaN
# 3484  3485  2025-02-25T00:00:00     1001  subscription_started        9.99
# 3485  3486  2025-02-25T00:00:00     1002           app_install         NaN
#
# [3486 rows x 5 columns]

# %%
events_df.drop(events_df[events_df['created_at']>pd.Timestamp.now()].index,axis = 0,inplace=True)

# %%
events_df.shape
# Out:
# (3293, 5)

# %%
print(3486-3293,' rows are dropped from events_df')
# Out:
# 193  rows are dropped from events_df

# %%
#Value count by columns for Users df


for  i in users_df.columns:
    print("-"*18+"  ",i,"  "+"-"*18)
    print('There are ',users_df[i].nunique(),f' unique records of {i}',end= '\n\n')
    print(users_df[i].value_counts(ascending=False),end='\n\n\n\n')
# Out:
# ------------------   id   ------------------
# There are  1002  unique records of id
#
# id
# 1       1
# 673     1
# 660     1
# 661     1
# 662     1
#        ..
# 340     1
# 341     1
# 342     1
# 343     1
# 1002    1
# Name: count, Length: 1002, dtype: int64
#
#
#
# ------------------   created_at   ------------------
# There are  384  unique records of created_at
#
# created_at
# 2024-07-01T00:00:00    8
# 2024-10-24T00:00:00    8
# 2024-08-15T00:00:00    7
# 2024-11-13T00:00:00    7
# 2024-07-06T00:00:00    6
#                       ..
# 2024-03-03T00:00:00    1
# 2024-12-12T00:00:00    1
# 2024-06-06T00:00:00    1
# 2024-08-02T00:00:00    1
# 2024-10-13T00:00:00    1
# Name: count, Length: 384, dtype: int64
#
#
#
# ------------------   attribution_source   ------------------
# There are  3  unique records of attribution_source
#
# attribution_source
# tiktok       352
# organic      344
# instagram    306
# Name: count, dtype: int64
#
#
#
# ------------------   country   ------------------
# There are  3  unique records of country
#
# country
# TR    354
# US    340
# NL    308
# Name: count, dtype: int64
#
#
#
# ------------------   name   ------------------
# There are  102  unique records of name
#
# name
# Henry Jones         18
# David Anderson      18
# Ivy Anderson        16
# Alice Smith         16
# Alice Moore         16
#                     ..
# Charlie Williams     5
# Ivy Miller           4
# Jack Brown           2
# Bruce Wayne          1
# Clark Kent           1
# Name: count, Length: 102, dtype: int64

# %%
#Value count by columns for Users Eventdf

for  i in events_df.columns:
    print("-"*18+"  ",i,"  "+"-"*18)
    print('There are ',events_df[i].nunique(),f' unique records of {i}',end= '\n\n')
    print(events_df[i].value_counts(ascending=False),end='\n\n\n\n')
# Out:
# ------------------   id   ------------------
# There are  3293  unique records of id
#
# id
# 1       1
# 2315    1
# 2302    1
# 2303    1
# 2304    1
#        ..
# 1166    1
# 1167    1
# 1168    1
# 1169    1
# 3481    1
# Name: count, Length: 3293, dtype: int64
#
#
#
# ------------------   created_at   ------------------
# There are  418  unique records of created_at
#
# created_at
# 2025-02-15    17
# 2024-05-14    17
# 2025-02-13    16
# 2025-01-05    16
# 2025-02-01    16
#               ..
# 2025-01-20     2
# 2024-03-22     2
# 2024-01-26     2
# 2024-01-06     1
# 2024-01-16     1
# Name: count, Length: 418, dtype: int64
#
#
#
# ------------------   user_id   ------------------
# There are  1000  unique records of user_id
#
# user_id
# 359    8
# 102    8
# 311    8
# 24     8
# 819    8
#       ..
# 220    1
# 786    1
# 224    1
# 387    1
# 504    1
# Name: count, Length: 1000, dtype: int64
#
#
#
# ------------------   event_name   ------------------
# There are  6  unique records of event_name
#
# event_name
# app_install               1000
# trial_started              681
# subscription_renewed       639
# subscription_started       476
# subscription_cancelled     300
# trial_cancelled            197
# Name: count, dtype: int64
#
#
#
# ------------------   amount_usd   ------------------
# There are  3  unique records of amount_usd
#
# amount_usd
# 4.99    396
# 9.99    367
# 8.99    352
# Name: count, dtype: int64

# %%
#Create new dataframe having missing values of amount_usd column
# Addressing missing values in Users event df

null_df = events_df[events_df['amount_usd'].isnull()]

# %%
#groupby created_at

#There is no make sense result grouping by created_at !... 

null_df.groupby(['created_at'])['created_at'].count()
# Out:
# created_at
# 2024-01-01    3
# 2024-01-02    2
# 2024-01-03    3
# 2024-01-04    3
# 2024-01-05    4
#              ..
# 2025-02-17    1
# 2025-02-18    2
# 2025-02-19    2
# 2025-02-20    1
# 2025-02-21    1
# Name: created_at, Length: 417, dtype: int64

# %%
#groupby event_name

#In this analysis we realize that in those subcategory of 
#event_name (app_install,subscription_cancelled,trial_cancelled,trial_started) No Cost
#that s why the values are null 

null_df.groupby(['event_name'])['event_name'].count()
# Out:
# event_name
# app_install               1000
# subscription_cancelled     300
# trial_cancelled            197
# trial_started              681
# Name: event_name, dtype: int64

# %% [markdown]
# ## Core Tasks

# %% [markdown]
# #### Join the table for handling core  tasks

# %%
#Join dataframe to combine country and amount_usd at the same dataframe
#this allow calculate revenue by country
#As noted in the document user_id in Events Tbale is reference of id in Users table so mergen based on those columns

# %%
df = pd.merge(users_df,events_df, how = 'inner', left_on = 'id',right_on = 'user_id')

# %%
df.head()
# Out:
#    id_x         created_at_x attribution_source country         name  id_y  \
# 0     1  2024-05-07T00:00:00          instagram      US    Eve Brown     1
# 1     1  2024-05-07T00:00:00          instagram      US    Eve Brown     2
# 2     1  2024-05-07T00:00:00          instagram      US    Eve Brown     3
# 3     2  2024-10-12T00:00:00          instagram      NL  Frank Moore     4
# 4     2  2024-10-12T00:00:00          instagram      NL  Frank Moore     5
#
#   created_at_y  user_id       event_name  amount_usd
# 0   2024-05-07        1      app_install         NaN
# 1   2024-05-12        1    trial_started         NaN
# 2   2024-05-24        1  trial_cancelled         NaN
# 3   2024-10-12        2      app_install         NaN
# 4   2024-10-13        2    trial_started         NaN

# %%
#remove  idle created columns after merging

df.drop(['id_y','created_at_y'],axis =1,inplace=True)

# %%
#rename suffixed columns into original

df.rename({'id_x':'id','created_at_x':'created_at'},inplace=True,axis=1)

# %%
#keep a copy of dataframe just in case

df_backup = df.copy()

# %%
df
# Out:
#         id           created_at attribution_source country           name  \
# 0        1  2024-05-07T00:00:00          instagram      US      Eve Brown
# 1        1  2024-05-07T00:00:00          instagram      US      Eve Brown
# 2        1  2024-05-07T00:00:00          instagram      US      Eve Brown
# 3        2  2024-10-12T00:00:00          instagram      NL    Frank Moore
# 4        2  2024-10-12T00:00:00          instagram      NL    Frank Moore
# ...    ...                  ...                ...     ...            ...
# 3288   999  2024-12-24T00:00:00            organic      NL  Charlie Davis
# 3289   999  2024-12-24T00:00:00            organic      NL  Charlie Davis
# 3290   999  2024-12-24T00:00:00            organic      NL  Charlie Davis
# 3291  1000  2025-02-13T00:00:00            organic      NL  Jack Anderson
# 3292  1000  2025-02-13T00:00:00            organic      NL  Jack Anderson
#
#       user_id            event_name  amount_usd
# 0           1           app_install         NaN
# 1           1         trial_started         NaN
# 2           1       trial_cancelled         NaN
# 3           2           app_install         NaN
# 4           2         trial_started         NaN
# ...       ...                   ...         ...
# 3288      999         trial_started         NaN
# 3289      999  subscription_started        8.99
# 3290      999  subscription_renewed        8.99
# 3291     1000           app_install         NaN
# 3292     1000         trial_started         NaN
#
# [3293 rows x 8 columns]

# %%
#Convert created_at column  into datetime format

df['created_at'] = pd.to_datetime(df['created_at'])

# %%
#check missing values after joining. This might be to confirm if joining is correct or not

df.isnull().sum()
# Out:
# id                       0
# created_at               0
# attribution_source       0
# country                  0
# name                     0
# user_id                  0
# event_name               0
# amount_usd            2178
# dtype: int64

# %% [markdown]
# ### 1 -  Calculate the total revenue generated from subscriptions for each country

# %%
df.groupby('country')['amount_usd'].sum()
# Out:
# country
# NL    3164.48
# TR    1976.04
# US    3666.33
# Name: amount_usd, dtype: float64

# %% [markdown]
# ### 2 - Calculate the total number of trials given to users who came from instagram

# %%
df[(df['attribution_source']=='instagram')&(df['event_name']=='trial_started')]
# Out:
#        id created_at attribution_source country          name  user_id  \
# 1       1 2024-05-07          instagram      US     Eve Brown        1
# 4       2 2024-10-12          instagram      NL   Frank Moore        2
# 44     12 2024-01-08          instagram      US  Frank Miller       12
# 63     15 2024-07-10          instagram      US    Bob Miller       15
# 66     16 2024-04-26          instagram      NL   Alice Brown       16
# ...   ...        ...                ...     ...           ...      ...
# 3238  981 2024-04-16          instagram      US    Eve Wilson      981
# 3262  989 2025-01-12          instagram      NL   Alice Jones      989
# 3265  990 2024-11-24          instagram      TR   David Davis      990
# 3270  992 2025-02-07          instagram      US   Grace Jones      992
# 3275  995 2024-09-30          instagram      US   Frank Smith      995
#
#          event_name  amount_usd
# 1     trial_started         NaN
# 4     trial_started         NaN
# 44    trial_started         NaN
# 63    trial_started         NaN
# 66    trial_started         NaN
# ...             ...         ...
# 3238  trial_started         NaN
# 3262  trial_started         NaN
# 3265  trial_started         NaN
# 3270  trial_started         NaN
# 3275  trial_started         NaN
#
# [209 rows x 8 columns]

# %%
#Check each trial record belongs to unique user_id

df[(df['attribution_source']=='instagram')&(df['event_name']=='trial_started')]['user_id'].nunique()
# Out:
# 209

# %%
print('Amount of trials from intagram :',df[(df['attribution_source']=='instagram')&(df['event_name']=='trial_started')]['event_name'].count())
# Out:
# Amount of trials from intagram : 209

# %% [markdown]
# ### 3 - Create a new column named 'acquisition_channel' by categorizing users based on their 'attribution_source'

# %%
#Use list comprehension based on attribution_source values 'Paid' for instagram and tiktok and Organic for organic
#Crete new column

df['acquisition_channel'] = pd.Series(['Organic' if i=='organic' else 'Paid' for i in df['attribution_source']])

# %%
df.sample(20)
# Out:
#        id created_at attribution_source country            name  user_id  \
# 459   145 2024-03-25             tiktok      NL  Alice Williams      145
# 1022  309 2024-05-25          instagram      US   Charlie Smith      309
# 573   179 2024-04-04            organic      US     Frank Brown      179
# 1872  568 2024-04-01          instagram      US  Frank Williams      568
# 1562  472 2024-10-29            organic      TR      Jack Smith      472
# 1767  531 2024-09-28          instagram      TR      Jack Moore      531
# 347   109 2024-08-29             tiktok      US    Ivy Williams      109
# 209    61 2024-12-15             tiktok      US    David Taylor       61
# 1456  444 2025-01-08            organic      NL   Charlie Jones      444
# 254    77 2025-01-05            organic      NL      Bob Wilson       77
# 3275  995 2024-09-30          instagram      US     Frank Smith      995
# 1181  359 2024-03-23             tiktok      US       Eve Brown      359
# 2011  612 2024-09-06             tiktok      US     Grace Moore      612
# 2348  710 2024-02-10             tiktok      TR     Alice Smith      710
# 2975  905 2024-12-18             tiktok      NL     David Moore      905
# 2520  765 2024-04-17             tiktok      NL       Eve Jones      765
# 213    63 2025-02-09          instagram      TR       Bob Davis       63
# 497   158 2024-07-11          instagram      NL      Ivy Taylor      158
# 1172  357 2024-02-23            organic      TR      Bob Taylor      357
# 1681  506 2025-01-27            organic      NL     Henry Jones      506
#
#                   event_name  amount_usd acquisition_channel
# 459              app_install         NaN                Paid
# 1022    subscription_renewed        9.99                Paid
# 573     subscription_started        9.99             Organic
# 1872    subscription_renewed        9.99                Paid
# 1562  subscription_cancelled         NaN             Organic
# 1767    subscription_renewed        4.99                Paid
# 347              app_install         NaN                Paid
# 209            trial_started         NaN                Paid
# 1456           trial_started         NaN             Organic
# 254          trial_cancelled         NaN             Organic
# 3275           trial_started         NaN                Paid
# 1181    subscription_renewed        9.99                Paid
# 2011             app_install         NaN                Paid
# 2348           trial_started         NaN                Paid
# 2975             app_install         NaN                Paid
# 2520    subscription_renewed        8.99                Paid
# 213            trial_started         NaN                Paid
# 497     subscription_renewed        8.99                Paid
# 1172             app_install         NaN             Organic
# 1681         trial_cancelled         NaN             Organic

# %% [markdown]
#  ### 4 - Analyze the trial-to-subscription conversion rate :
#
# - Calculate the overall conversion rate
# - Break down the conversion rate by attribution_source

# %%
df['event_name'].value_counts()
# Out:
# event_name
# app_install               1000
# trial_started              681
# subscription_renewed       639
# subscription_started       476
# subscription_cancelled     300
# trial_cancelled            197
# Name: count, dtype: int64

# %%
#For calculation the trial to subscription overall. just divide subscription_started by trial_started values

print('Overall conversion rate of trial-to-subscription : ', f'%{round((481/682)*100,2)}')
# Out:
# Overall conversion rate of trial-to-subscription :  %70.53

# %%
#Groupby the dataframe based on attribution_source and return value_counts
#Then find trial to subscription rate by subcategory of attribution_source

df.groupby('attribution_source')[['attribution_source','event_name']].value_counts()
# Out:
# attribution_source  event_name
# instagram           app_install               305
#                     trial_started             209
#                     subscription_renewed      198
#                     subscription_started      148
#                     subscription_cancelled     95
#                     trial_cancelled            60
# organic             app_install               343
#                     subscription_renewed      238
#                     trial_started             236
#                     subscription_started      167
#                     subscription_cancelled    107
#                     trial_cancelled            66
# tiktok              app_install               352
#                     trial_started             236
#                     subscription_renewed      203
#                     subscription_started      161
#                     subscription_cancelled     98
#                     trial_cancelled            71
# Name: count, dtype: int64

# %%
#As seen the calculation, type of attribution sources do not influent conversion rate specifically.


print('Conversion rate of trial-to-subscription by "instagram" : ', f'%{round((149/210)*100,2)}',end='\n\n')
print('Conversion rate of trial-to-subscription by "organic" : ', f'%{round((169/236)*100,2)}',end='\n\n')
print('Conversion rate of trial-to-subscription by "tiktok" : ', f'%{round((163/236)*100,2)}')
# Out:
# Conversion rate of trial-to-subscription by "instagram" :  %70.95
#
# Conversion rate of trial-to-subscription by "organic" :  %71.61
#
# Conversion rate of trial-to-subscription by "tiktok" :  %69.07

# %% [markdown]
#  ### 5 - Calculate the median subscription duration (in months) for each country

# %%
#convert created_at column of event_df dataframe

# %%
#Create pivot table on events_df. This allow us compare date of events according to userd_id
#We will see each event date under a column named with events for each user_id 

df_pivot = events_df.pivot_table(index='user_id', columns='event_name', values='created_at')

# %%
#Adding countries into pivot table by merging based on user_id and id in users_Df

df_pivot = pd.merge(users_df,df_pivot, how = 'inner', left_on = 'id',right_on = 'user_id')

# %%
df_pivot
# Out:
#        id           created_at attribution_source country           name  \
# 0       1  2024-05-07T00:00:00          instagram      US      Eve Brown
# 1       2  2024-10-12T00:00:00          instagram      NL    Frank Moore
# 2       3  2024-10-15T00:00:00             tiktok      TR   Ivy Anderson
# 3       4  2024-08-28T00:00:00             tiktok      TR    Alice Brown
# 4       5  2024-04-03T00:00:00            organic      NL      Bob Moore
# ..    ...                  ...                ...     ...            ...
# 995   996  2025-01-28T00:00:00            organic      TR  Jack Anderson
# 996   997  2024-03-06T00:00:00            organic      NL      Bob Jones
# 997   998  2025-02-01T00:00:00          instagram      TR      Bob Davis
# 998   999  2024-12-24T00:00:00            organic      NL  Charlie Davis
# 999  1000  2025-02-13T00:00:00            organic      NL  Jack Anderson
#
#     app_install subscription_cancelled subscription_renewed  \
# 0    2024-05-07                    NaT                  NaT
# 1    2024-10-12             2025-02-12           2024-12-19
# 2    2024-10-15             2025-01-20           2024-12-20
# 3    2024-08-28                    NaT                  NaT
# 4    2024-04-03                    NaT                  NaT
# ..          ...                    ...                  ...
# 995  2025-01-28                    NaT                  NaT
# 996  2024-03-06                    NaT                  NaT
# 997  2025-02-01                    NaT                  NaT
# 998  2024-12-24                    NaT           2025-02-02
# 999  2025-02-13                    NaT                  NaT
#
#     subscription_started trial_cancelled trial_started
# 0                    NaT      2024-05-24    2024-05-12
# 1             2024-10-20             NaT    2024-10-13
# 2             2024-10-21             NaT    2024-10-19
# 3                    NaT      2024-09-06    2024-08-31
# 4                    NaT             NaT           NaT
# ..                   ...             ...           ...
# 995           2025-02-06             NaT    2025-02-01
# 996                  NaT      2024-03-16    2024-03-08
# 997                  NaT             NaT           NaT
# 998           2025-01-03             NaT    2024-12-29
# 999                  NaT             NaT    2025-02-15
#
# [1000 rows x 11 columns]

# %%
#Create new df_pivot just store subscription based columns and essential columns

df_pivot_subscription = df_pivot[['id','country','subscription_cancelled','subscription_started']]

# %%
#For subscription not canceled , we calculate duration through subtraction 'subscription_started' from 'now'

now = pd.Timestamp.now()

df_pivot_subscription['duration-InMonth'] = round(
    ((df_pivot_subscription['subscription_cancelled'].fillna(now) - df_pivot_subscription['subscription_started']).dt.days) / 30, 2
)
# Out:
# C:\Users\manai\AppData\Local\Temp\ipykernel_3816\1824854087.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pivot_subscription['duration-InMonth'] = round(

# %%
#id stands for user_id aswell so when merging we create our dataframe based on id and user_id

df_pivot_subscription
# Out:
#        id country subscription_cancelled subscription_started  \
# 0       1      US                    NaT                  NaT
# 1       2      NL             2025-02-12           2024-10-20
# 2       3      TR             2025-01-20           2024-10-21
# 3       4      TR                    NaT                  NaT
# 4       5      NL                    NaT                  NaT
# ..    ...     ...                    ...                  ...
# 995   996      TR                    NaT           2025-02-06
# 996   997      NL                    NaT                  NaT
# 997   998      TR                    NaT                  NaT
# 998   999      NL                    NaT           2025-01-03
# 999  1000      NL                    NaT                  NaT
#
#      duration-InMonth
# 0                 NaN
# 1                3.83
# 2                3.03
# 3                 NaN
# 4                 NaN
# ..                ...
# 995              0.50
# 996               NaN
# 997               NaN
# 998              1.63
# 999               NaN
#
# [1000 rows x 5 columns]

# %%
#Groupby on country and return median value of 'duration-InMonth' for each country

df_pivot_subscription[df_pivot_subscription['duration-InMonth'].notna()].groupby('country')['duration-InMonth'].median()
# Out:
# country
# NL    2.515
# TR    2.400
# US    2.315
# Name: duration-InMonth, dtype: float64

# %% [markdown]
# ### 6 - Calculate the Average Lifetime Value (LTV) by country

# %%
#Calculate average revenue per user. Find total revenue and unique amount of users


total_revenue = df['amount_usd'].sum()
total_users = df['user_id'].nunique()  
rev_by_user = total_revenue / total_users

# %%
#Calculate "average lifespan" from duration-in month - so revenue taken only from subscription 
#We can use our "df_pivot_subscription" dataframe

average_lifespan = df_pivot_subscription['duration-InMonth'].mean()

# %%
average_lifespan
# Out:
# 3.347752100840336

# %%
#Now Calculate LTV - Lifetiem Values by multiplication average lifespan with average revenue by user

LTV = round(rev_by_user*average_lifespan,2)

# %%
print('Average Lifetime Value(LTV) :',f'${LTV}')
# Out:
# Average Lifetime Value(LTV) : $29.48

# %% [markdown]
# ## BONUS Tasks

# %% [markdown]
# ### 7 - Predict the churn probability for use #1002 (Clark Kent)
#
# - Use any relevant features from the dataset
# - Explain your model selection and feature engineering process
# - Provide confidence intervals if applicaple

# %%
df_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1000 non-null   int64
#  1   created_at              1000 non-null   object
#  2   attribution_source      1000 non-null   object
#  3   country                 1000 non-null   object
#  4   name                    1000 non-null   object
#  5   app_install             1000 non-null   datetime64[ns]
#  6   subscription_cancelled  300 non-null    datetime64[ns]
#  7   subscription_renewed    336 non-null    datetime64[ns]
#  8   subscription_started    476 non-null    datetime64[ns]
#  9   trial_cancelled         197 non-null    datetime64[ns]
#  10  trial_started           681 non-null    datetime64[ns]
# dtypes: datetime64[ns](6), int64(1), object(4)
# memory usage: 86.1+ KB

# %%
events_df.groupby('user_id').count()
# Out:
#          id  created_at  event_name  amount_usd
# user_id
# 1         3           3           3           0
# 2         7           7           7           4
# 3         7           7           7           4
# 4         3           3           3           0
# 5         1           1           1           0
# ...      ..         ...         ...         ...
# 996       3           3           3           1
# 997       3           3           3           0
# 998       1           1           1           0
# 999       4           4           4           2
# 1000      2           2           2           0
#
# [1000 rows x 4 columns]

# %%
df[df['user_id'].isin([2,3])]
# Out:
#     id created_at attribution_source country          name  user_id  \
# 3    2 2024-10-12          instagram      NL   Frank Moore        2
# 4    2 2024-10-12          instagram      NL   Frank Moore        2
# 5    2 2024-10-12          instagram      NL   Frank Moore        2
# 6    2 2024-10-12          instagram      NL   Frank Moore        2
# 7    2 2024-10-12          instagram      NL   Frank Moore        2
# 8    2 2024-10-12          instagram      NL   Frank Moore        2
# 9    2 2024-10-12          instagram      NL   Frank Moore        2
# 10   3 2024-10-15             tiktok      TR  Ivy Anderson        3
# 11   3 2024-10-15             tiktok      TR  Ivy Anderson        3
# 12   3 2024-10-15             tiktok      TR  Ivy Anderson        3
# 13   3 2024-10-15             tiktok      TR  Ivy Anderson        3
# 14   3 2024-10-15             tiktok      TR  Ivy Anderson        3
# 15   3 2024-10-15             tiktok      TR  Ivy Anderson        3
# 16   3 2024-10-15             tiktok      TR  Ivy Anderson        3
#
#                 event_name  amount_usd acquisition_channel
# 3              app_install         NaN                Paid
# 4            trial_started         NaN                Paid
# 5     subscription_started        8.99                Paid
# 6     subscription_renewed        8.99                Paid
# 7     subscription_renewed        8.99                Paid
# 8     subscription_renewed        8.99                Paid
# 9   subscription_cancelled         NaN                Paid
# 10             app_install         NaN                Paid
# 11           trial_started         NaN                Paid
# 12    subscription_started        4.99                Paid
# 13    subscription_renewed        4.99                Paid
# 14    subscription_renewed        4.99                Paid
# 15    subscription_renewed        4.99                Paid
# 16  subscription_cancelled         NaN                Paid

# %%
events_df[events_df['user_id'].isin([2,3])]
# Out:
#     id created_at  user_id              event_name  amount_usd
# 3    4 2024-10-12        2             app_install         NaN
# 4    5 2024-10-13        2           trial_started         NaN
# 5    6 2024-10-20        2    subscription_started        8.99
# 6    7 2024-11-19        2    subscription_renewed        8.99
# 7    8 2024-12-19        2    subscription_renewed        8.99
# 8    9 2025-01-18        2    subscription_renewed        8.99
# 9   10 2025-02-12        2  subscription_cancelled         NaN
# 10  11 2024-10-15        3             app_install         NaN
# 11  12 2024-10-19        3           trial_started         NaN
# 12  13 2024-10-21        3    subscription_started        4.99
# 13  14 2024-11-20        3    subscription_renewed        4.99
# 14  15 2024-12-20        3    subscription_renewed        4.99
# 15  16 2025-01-19        3    subscription_renewed        4.99
# 16  17 2025-01-20        3  subscription_cancelled         NaN

# %%
df_pivot[df_pivot['id'].isin([2,3])]
# Out:
#    id           created_at attribution_source country          name  \
# 1   2  2024-10-12T00:00:00          instagram      NL   Frank Moore
# 2   3  2024-10-15T00:00:00             tiktok      TR  Ivy Anderson
#
#   app_install subscription_cancelled subscription_renewed  \
# 1  2024-10-12             2025-02-12           2024-12-19
# 2  2024-10-15             2025-01-20           2024-12-20
#
#   subscription_started trial_cancelled trial_started
# 1           2024-10-20             NaT    2024-10-13
# 2           2024-10-21             NaT    2024-10-19

# %%
df_pivot['trial_cancelled'].value_counts(dropna= True)
# Out:
# trial_cancelled
# 2024-07-20    3
# 2024-07-17    3
# 2024-06-19    3
# 2025-01-14    3
# 2024-10-19    2
#              ..
# 2024-05-03    1
# 2024-12-06    1
# 2024-07-14    1
# 2024-09-11    1
# 2024-03-16    1
# Name: count, Length: 164, dtype: int64

# %%
events_df
# Out:
#         id created_at  user_id            event_name  amount_usd
# 0        1 2024-05-07        1           app_install         NaN
# 1        2 2024-05-12        1         trial_started         NaN
# 2        3 2024-05-24        1       trial_cancelled         NaN
# 3        4 2024-10-12        2           app_install         NaN
# 4        5 2024-10-13        2         trial_started         NaN
# ...    ...        ...      ...                   ...         ...
# 3474  3475 2024-12-29      999         trial_started         NaN
# 3475  3476 2025-01-03      999  subscription_started        8.99
# 3476  3477 2025-02-02      999  subscription_renewed        8.99
# 3479  3480 2025-02-13     1000           app_install         NaN
# 3480  3481 2025-02-15     1000         trial_started         NaN
#
# [3293 rows x 5 columns]

# %%
df_pivot
# Out:
#        id           created_at attribution_source country           name  \
# 0       1  2024-05-07T00:00:00          instagram      US      Eve Brown
# 1       2  2024-10-12T00:00:00          instagram      NL    Frank Moore
# 2       3  2024-10-15T00:00:00             tiktok      TR   Ivy Anderson
# 3       4  2024-08-28T00:00:00             tiktok      TR    Alice Brown
# 4       5  2024-04-03T00:00:00            organic      NL      Bob Moore
# ..    ...                  ...                ...     ...            ...
# 995   996  2025-01-28T00:00:00            organic      TR  Jack Anderson
# 996   997  2024-03-06T00:00:00            organic      NL      Bob Jones
# 997   998  2025-02-01T00:00:00          instagram      TR      Bob Davis
# 998   999  2024-12-24T00:00:00            organic      NL  Charlie Davis
# 999  1000  2025-02-13T00:00:00            organic      NL  Jack Anderson
#
#     app_install subscription_cancelled subscription_renewed  \
# 0    2024-05-07                    NaT                  NaT
# 1    2024-10-12             2025-02-12           2024-12-19
# 2    2024-10-15             2025-01-20           2024-12-20
# 3    2024-08-28                    NaT                  NaT
# 4    2024-04-03                    NaT                  NaT
# ..          ...                    ...                  ...
# 995  2025-01-28                    NaT                  NaT
# 996  2024-03-06                    NaT                  NaT
# 997  2025-02-01                    NaT                  NaT
# 998  2024-12-24                    NaT           2025-02-02
# 999  2025-02-13                    NaT                  NaT
#
#     subscription_started trial_cancelled trial_started
# 0                    NaT      2024-05-24    2024-05-12
# 1             2024-10-20             NaT    2024-10-13
# 2             2024-10-21             NaT    2024-10-19
# 3                    NaT      2024-09-06    2024-08-31
# 4                    NaT             NaT           NaT
# ..                   ...             ...           ...
# 995           2025-02-06             NaT    2025-02-01
# 996                  NaT      2024-03-16    2024-03-08
# 997                  NaT             NaT           NaT
# 998           2025-01-03             NaT    2024-12-29
# 999                  NaT             NaT    2025-02-15
#
# [1000 rows x 11 columns]
